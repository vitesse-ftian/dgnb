# %% [markdown]
# # View and Analyze Deepgreen Error Logs

# %% [markdown]
# Open connection to database.

# %%
import dg.conn
from dg.admin import errlog
con = dg.conn.Conn("host=localhost dbname=postgres")
print (con.ver)
# Out:
# 4

# %% [markdown]
# Retrieve deepgreen errors, by default, the lv is 'ERROR+'.  We want most recent 100 errors.   Default tablefmt is psql, but let's do fancy_grid.

# %%
et = errlog.xt_errlog(con, lv = 'ERROR+', limit = 100)
# print(et.show(tablefmt='fancy_grid'))

# %%
# Whewww, too noisy.
xt = et.select(select='logtime, logseverity, loguser, logdatabase, logsegment, logmessage')
print(xt.show(tablefmt='fancy_grid'))
# Out:
# ╒══════════════════════════════════╤═══════════════╤═══════════╤═══════════════╤══════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╕
# │ logtime                          │ logseverity   │ loguser   │ logdatabase   │ logsegment   │ logmessage                                                                                                         │
# ╞══════════════════════════════════╪═══════════════╪═══════════╪═══════════════╪══════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 2018-01-16 11:14:08.184436-08:00 │ ERROR         │ ftian     │ tpch1f        │ seg-1        │ external command ended with error.   File "phi_main.py", line 52  (seg1 slice1 ftian-desktop:40001 pid=1695)       │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 11:14:08.036741-08:00 │ ERROR         │ ftian     │ tpch1f        │ seg2         │ external command ended with error.   File "phi_main.py", line 52                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 11:14:08.033893-08:00 │ ERROR         │ ftian     │ tpch1f        │ seg0         │ external command ended with error.   File "phi_main.py", line 52                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 11:14:08.031511-08:00 │ ERROR         │ ftian     │ tpch1f        │ seg1         │ external command ended with error.   File "phi_main.py", line 52                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 11:13:08.169523-08:00 │ ERROR         │ ftian     │ tpch1f        │ seg-1        │ external command ended with error.   File "phi_main.py", line 52  (seg0 slice1 ftian-desktop:40000 pid=1522)       │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 11:13:08.023175-08:00 │ ERROR         │ ftian     │ tpch1f        │ seg2         │ external command ended with error.   File "phi_main.py", line 52                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 11:13:08.020907-08:00 │ ERROR         │ ftian     │ tpch1f        │ seg0         │ external command ended with error.   File "phi_main.py", line 52                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 11:13:08.020906-08:00 │ ERROR         │ ftian     │ tpch1f        │ seg1         │ external command ended with error.   File "phi_main.py", line 52                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 11:12:52.835507-08:00 │ ERROR         │ ftian     │ tpch1f        │ seg-1        │ column tmp_1.vmstat_sed does not exist                                                                             │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:50:32.981353-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ external command ended with error.   File "phi_main.py", line 54  (seg2 slice1 ftian-desktop:40002 pid=32427)      │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:50:32.980623-08:00 │ ERROR         │ ftian     │ ftian         │ seg1         │ external command ended with error.   File "phi_main.py", line 54                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:50:32.977785-08:00 │ ERROR         │ ftian     │ ftian         │ seg0         │ external command ended with error.   File "phi_main.py", line 54                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:50:32.972656-08:00 │ ERROR         │ ftian     │ ftian         │ seg2         │ external command ended with error.   File "phi_main.py", line 54                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:26:50.998246-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ external command ended with error. Traceback (most recent call last):  (seg1 slice1 ftian-desktop:40001 pid=30217) │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:26:50.997659-08:00 │ ERROR         │ ftian     │ ftian         │ seg2         │ external command ended with error. Traceback (most recent call last):                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:26:50.989252-08:00 │ ERROR         │ ftian     │ ftian         │ seg0         │ external command ended with error. Traceback (most recent call last):                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:26:50.988504-08:00 │ ERROR         │ ftian     │ ftian         │ seg1         │ external command ended with error. Traceback (most recent call last):                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:26:05.053733-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ external command ended with error. Traceback (most recent call last):  (seg2 slice1 ftian-desktop:40002 pid=30135) │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:26:05.053153-08:00 │ ERROR         │ ftian     │ ftian         │ seg1         │ external command ended with error. Traceback (most recent call last):                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:26:05.040694-08:00 │ ERROR         │ ftian     │ ftian         │ seg0         │ external command ended with error. Traceback (most recent call last):                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:26:05.013848-08:00 │ ERROR         │ ftian     │ ftian         │ seg2         │ external command ended with error. Traceback (most recent call last):                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:23:17.128987-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ external command ended with error. Traceback (most recent call last):  (seg2 slice1 ftian-desktop:40002 pid=29910) │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:23:17.128171-08:00 │ ERROR         │ ftian     │ ftian         │ seg1         │ external command ended with error. Traceback (most recent call last):                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:23:17.127108-08:00 │ ERROR         │ ftian     │ ftian         │ seg0         │ external command ended with error. Traceback (most recent call last):                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:23:17.086012-08:00 │ ERROR         │ ftian     │ ftian         │ seg2         │ external command ended with error. Traceback (most recent call last):                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:22:37.944381-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ external command ended with error.   File "phi_main.py", line 37  (seg0 slice1 ftian-desktop:40000 pid=29850)      │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:22:37.943676-08:00 │ ERROR         │ ftian     │ ftian         │ seg2         │ external command ended with error.   File "phi_main.py", line 37                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:22:37.942826-08:00 │ ERROR         │ ftian     │ ftian         │ seg1         │ external command ended with error.   File "phi_main.py", line 37                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:22:37.940800-08:00 │ ERROR         │ ftian     │ ftian         │ seg0         │ external command ended with error.   File "phi_main.py", line 37                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:20:54.290818-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ Tranducer output type mismatch. (nodeTransducer.c:124)                                                             │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:17:30.057480-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ external command ended with error. Traceback (most recent call last):                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:16:10.625645-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ external command ended with error. Traceback (most recent call last):                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:14:06.660782-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ Tranducer output type mismatch. (nodeTransducer.c:124)                                                             │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 10:12:38.672927-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ Tranducer output type mismatch. (nodeTransducer.c:124)                                                             │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-16 09:30:08.832098-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ relation "gp_stat_activity" does not exist                                                                         │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 17:13:07.988349-08:00 │ FATAL         │           │               │ seg-1        │ terminating connection due to administrator command                                                                │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 17:13:07.983415-08:00 │ FATAL         │           │               │ seg-1        │ terminating connection due to administrator command                                                                │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 17:13:07.980535-08:00 │ FATAL         │           │               │ seg-1        │ terminating connection due to administrator command                                                                │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 17:13:07.979768-08:00 │ FATAL         │           │               │ seg-1        │ terminating connection due to administrator command                                                                │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 17:13:07.960612-08:00 │ FATAL         │ ftian     │ ftian         │ seg-1        │ terminating connection due to administrator command                                                                │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 17:13:07.946196-08:00 │ FATAL         │           │               │ seg-1        │ terminating connection due to administrator command                                                                │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 17:13:07.946145-08:00 │ FATAL         │ ftian     │ ftian         │ seg-1        │ terminating connection due to administrator command                                                                │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 17:13:07.946095-08:00 │ FATAL         │ ftian     │ postgres      │ seg-1        │ terminating connection due to administrator command                                                                │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 15:22:20.053494-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ relation "gp_toolkit.gp_system_logs" does not exist                                                                │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 15:22:16.925578-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ relation "gp_toolkit.gp_system_log" does not exist                                                                 │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 15:21:57.925186-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ schema "gp_toolkits" does not exist                                                                                │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 15:21:50.389999-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ relation "gp_toolkit.gp_system_log" does not exist                                                                 │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 14:35:18.183672-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ column "content_id" does not exist                                                                                 │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 14:34:38.239610-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ syntax error at or near "select"                                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 14:34:15.792324-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ column "sodtschemaname" does not exist                                                                             │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 14:12:02.249665-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ column "sodtschemaname" does not exist                                                                             │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 14:11:50.254153-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ column "sckcoeff" does not exist                                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 14:11:27.337661-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ column "sodtschemaname" does not exist                                                                             │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 13:04:19.075971-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ function bytein(cstring) does not exist                                                                            │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-13 13:04:11.982591-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ function bytain(cstring) does not exist                                                                            │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-12 22:26:31.902787-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ syntax error at or near "xt"                                                                                       │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-12 22:26:12.248984-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ syntax error at or near "xt"                                                                                       │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 21:20:28.319675-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ syntax error at or near ";"                                                                                        │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 21:04:36.202494-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ column seg.gp_segment_id does not exist                                                                            │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 21:04:15.022113-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ column "gp_segment_id" does not exist                                                                              │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 21:01:51.285886-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ schema "du_utils" does not exist                                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 20:26:53.902902-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ column "postevar74" of relation "telstra_hist" does not exist                                                      │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 20:21:33.585002-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ syntax error at or near "timezone"                                                                                 │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 20:17:36.845543-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ column "today" does not exist                                                                                      │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 20:16:58.567117-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ invalid input syntax for type timestamp with time zone: "3 days"                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 20:12:14.392128-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ schema "tcom_data" does not exist                                                                                  │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 20:08:57.179865-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ syntax error at or near "1"                                                                                        │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 20:08:49.893951-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ syntax error at or near "'day'"                                                                                    │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 20:03:54.038768-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ relation "ttt" already exists                                                                                      │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 20:03:48.833085-08:00 │ ERROR         │ ftian     │ ftian         │ seg-1        │ unrecognized parameter "compression"                                                                               │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:40.228618-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ ORDER/GROUP BY expression not found in targetlist (tlist.c:205)                                                    │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:39.563293-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ ORDER/GROUP BY expression not found in targetlist (tlist.c:205)                                                    │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:36.873966-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ division by zero  (seg0 slice12 ftian-desktop:40000 pid=27317)                                                     │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:36.870683-08:00 │ ERROR         │ ftian     │ regression    │ seg1         │ canceling MPP operation                                                                                            │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:36.693964-08:00 │ ERROR         │ ftian     │ regression    │ seg0         │ canceling MPP operation                                                                                            │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:36.641727-08:00 │ ERROR         │ ftian     │ regression    │ seg2         │ canceling MPP operation                                                                                            │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:35.501424-08:00 │ ERROR         │ ftian     │ regression    │ seg0         │ division by zero                                                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:31.895917-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ function complexquery() does not exist                                                                             │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:31.441449-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ role "gpadmin" already exists                                                                                      │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:31.441171-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ role "gpadmin" cannot be dropped because some objects depend on it                                                 │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:31.403110-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ resource queue "tbl16369_resq3" does not exist                                                                     │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:31.402706-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ resource queue "tbl16369_resq1" does not exist                                                                     │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:24.635851-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ language "plpythonu" already exists                                                                                │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:11.213895-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ column "b" is of type integer but expression is of type text                                                       │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:11.213173-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ column "b" is of type integer but expression is of type text                                                       │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:11.212483-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ column "b" is of type integer but expression is of type text                                                       │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:22:11.172045-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ relation "b" already exists                                                                                        │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:32.330158-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ schema "qp_query_execution" does not exist                                                                         │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:24.727151-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:22.352041-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:22.347632-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:21.935988-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:21.311384-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:20.490170-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:20.356664-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:19.744757-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:19.332945-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:18.482229-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:17.406954-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ├──────────────────────────────────┼───────────────┼───────────┼───────────────┼──────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2018-01-11 09:21:15.523836-08:00 │ ERROR         │ ftian     │ regression    │ seg-1        │ GROUPING SETS / ROLLUP / CUBE columns ambiguous.                                                                   │
# ╘══════════════════════════════════╧═══════════════╧═══════════╧═══════════════╧══════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╛
